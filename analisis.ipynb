# %%
from Mis_funciones import *

# %% [markdown]
# ### leo archivo

# %%
df=leer_archivo('200820COVID19MEXICO.csv')

# %% [markdown]
# ### información del archio

# %%
info_dataFrame(df)
# Out:
# tamaño  1226117
# total columnas 35
# Tipos de columnas
# FECHA_ACTUALIZACION    object
# ID_REGISTRO            object
# ORIGEN                  int64
# SECTOR                  int64
# ENTIDAD_UM              int64
# SEXO                    int64
# ENTIDAD_NAC             int64
# ENTIDAD_RES             int64
# MUNICIPIO_RES           int64
# TIPO_PACIENTE           int64
# FECHA_INGRESO          object
# FECHA_SINTOMAS         object
# FECHA_DEF              object
# INTUBADO                int64
# NEUMONIA                int64
# EDAD                    int64
# NACIONALIDAD            int64
# EMBARAZO                int64
# HABLA_LENGUA_INDIG      int64
# DIABETES                int64
# EPOC                    int64
# ASMA                    int64
# INMUSUPR                int64
# HIPERTENSION            int64
# OTRA_COM                int64
# CARDIOVASCULAR          int64
# OBESIDAD                int64
# RENAL_CRONICA           int64
# TABAQUISMO              int64
# ...

# %% [markdown]
# ### agrupo edades

# %%
df=agrupar_edades(df)

# %%
df_r=UCI_1_2(df)

# %%
len(df_r)
# Out:
# 225920

# %% [markdown]
# # Cada columna esta graficada para los 32 estados

# %% [markdown]
# ### Origen

# %%
Columnas_SI_NO(df_r,"ORIGEN","lightblue","pink","green","purple")

# %% [markdown]
# ### sector de todo el pais

# %%
Columna_sector(df_r)

# %% [markdown]
# ## Entidad_um

# %%
#PENDIENTE
#Columna_entidad_UM(df_cdmx_SIN_99_97)

# %% [markdown]
# ### sexo

# %%
Columnas_SI_NO(df_r,"SEXO","lightblue","pink","green","purple")

# %% [markdown]
# ###  INTUBADO

# %%
Columnas_SI_NO(df_r,"INTUBADO","lightblue","pink","green","purple")

# %% [markdown]
# ### NEUMONIA

# %%
Columnas_SI_NO(df_r,"NEUMONIA","lightblue","pink","green","purple")

# %% [markdown]
# ### EDAD

# %%
Columna_edad(df_r)

# %% [markdown]
# ### EMBARAZO

# %%
Columnas_SI_NO(df_r,"EMBARAZO","lightblue","pink","green","purple")

# %% [markdown]
# ### HABLA_LENGUA_INDIG

# %%
Columnas_SI_NO(df_r,"HABLA_LENGUA_INDIG","lightblue","pink","green","purple")

# %% [markdown]
# ### Diabetes

# %%
Columnas_SI_NO(df_r,"DIABETES","lightblue","pink","green","purple")

# %% [markdown]
# ### Epoc

# %%
Columnas_SI_NO(df_r,"EPOC","lightblue","pink","green","purple")

# %% [markdown]
# ### ASMA

# %%
Columnas_SI_NO(df_r,"ASMA","lightblue","pink","green","purple")

# %% [markdown]
# ### INMUSUPR

# %%
Columnas_SI_NO(df_r,"INMUSUPR","lightblue","pink","green","purple")

# %% [markdown]
# ### HIPERTENSION

# %%
Columnas_SI_NO(df_r,"HIPERTENSION","lightblue","pink","green","purple")

# %% [markdown]
# ### OTRA_COMP

# %%
Columnas_SI_NO(df_r,"OTRA_COM","lightblue","pink","green","purple")

# %% [markdown]
# ### CARDIOVASCULAR

# %%
Columnas_SI_NO(df_r,"CARDIOVASCULAR","lightblue","pink","green","purple")

# %% [markdown]
# ### OBESIDAD

# %%
Columnas_SI_NO(df_r,"OBESIDAD","lightblue","pink","green","purple")

# %% [markdown]
# ### RENAL_CRONICA

# %%
Columnas_SI_NO(df_r,"RENAL_CRONICA","lightblue","pink","green","purple")

# %% [markdown]
# ### TABAQUISMO

# %%
Columnas_SI_NO(df_r,"TABAQUISMO","lightblue","pink","green","purple")

# %% [markdown]
# ### OTRO_CASO

# %%
Columnas_SI_NO(df_r,"OTRO_CASO","lightblue","pink","green","purple")

# %% [markdown]
# ### RESULTADO

# %%
Columnas_SI_NO(df_r,"RESULTADO","lightblue","pink","green","purple")

# %% [markdown]
# ### Migrante

# %%
#PENDIENTE
#Columnas_SI_NO(df_cdmx_SIN_99_97,"MIGRANTE","lightblue","pink","green","purple")

# %% [markdown]
# ### GRAFICA LAS COLUMNAS POR ORDEN DE RELACION CON UCI PARA CADA ESTADO

# %% [markdown]
# ### enfermedades o padecimientos

# %% [markdown]
# primeros 3 estados

# %%
num_estado=list(np.arange(1,33))
nombre_estados=[
    "AGUASCALIENTES",
    "BAJA_CALIFORNIA",
    "BAJA_CALIFORNIA",
    "CAMPECHE",
    "COAHUILA",
    "COLIMA",
     "CHIAPAS",
    "CHIHUAHUA",
    "CDMX",
    "DURANGO",
    "GUANAJUATO",
    "GUERRERO",
    "HIDALGO",
    "JALISCO",
    "MEXICO",
    "MICHOACAN",
    "MORELOS",
    "NAYARIT",
    "NUEVO_LEON",
    "OAXACA",
    "PUEBLA",
    "QUERETARO",
    "QUINTANA ROO",
    "SAN_LUIS",
    "SINALOA",
    "SONORA",
    "TABASCO",
    "TAMAULIPAS",
    "TLASCALA",
    "VERACRUZ",
    "YUCATAN",
    "ZACATECAZ",
 
]

for i in range(len(nombre_estados)):
    df_estado=df_r[(df_r['ENTIDAD_RES']== num_estado[i])]  #Selecciono renglones de estado indice_estado[i]  
    Graficar_enfermedades(df_estado,nombre_estados[i])

# %% [markdown]
# # OTROS

# %%
for i in range(len(nombre_estados)):
    df_estado=df_r[(df_r['ENTIDAD_RES']== num_estado[i])]  #Selecciono renglones de estado indice_estado[i]  
    asociar_otros(df_estado,nombre_estados[i])

# %%
tabla_de_contingencia(df_r,"UCI","EMBARAZO")
# Out:
# EMBARAZO     1      2      97   98     All
# UCI
# 1          206   7010   12188   28   19432
# 2         1876  82921  121431  260  206488
# All       2082  89931  133619  288  225920

# %%
asm=df_r[(df_r.ASMA<3)]

# %%
pd.crosstab(index=asm['UCI'], columns=asm["ASMA"]).apply(lambda r: r/r.sum() *100,axis=1)
# Out:
# ASMA         1          2
# UCI
# 1     2.290314  97.709686
# 2     2.438681  97.561319

# %%
pd.crosstab(index=asm['UCI'], columns=asm["ASMA"]).apply(lambda r: r/r.sum() *100,axis=0)
# Out:
# ASMA          1        2
# UCI
# 1      8.079883   8.5704
# 2     91.920117  91.4296

# %%
pd.crosstab(index=asm['UCI'], columns=asm["ASMA"])
# Out:
# ASMA     1       2
# UCI
# 1      441   18814
# 2     5017  200709
